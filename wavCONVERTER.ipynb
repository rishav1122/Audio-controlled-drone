# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Activation, Dense, Flatten, BatchNormalization,Dropout
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
import os, sys
import matplotlib.pyplot as plt
import librosa
from librosa import display
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
pip install pydub

# %%
from pydub import AudioSegment

# %%
os.chdir('/content/drive/MyDrive/Audio_controlled_drone/Dataset')
# !dir
# Out:
# Hover  Land  Move-backward  Move-forward  Move-left  Move-right  Take-off

# %%
hover = []
land = []
mback = []
mfor = []
mleft = []
mright = []
takeoff = []

hover = os.listdir('Hover')
land = os.listdir('Land')
mback = os.listdir('Move-backward')
mfor = os.listdir('Move-forward')
mleft = os.listdir('Move-left')
mright = os.listdir('Move-right')
takeoff = os.listdir('Take-off')

names_list  = ['hover', 'land', 'mback', 'mfor', 'takeoff', 'mleft', 'mright']
list = [hover, land, mback, mfor, takeoff, mleft, mright]

# %%
for g in names_list:
  path_audio = os.path.join('wavdata', f'{g}')
  os.makedirs(path_audio)

# %%
commandlst = ['Hover', 'Land', 'Move-backward',  'Move-forward', 'Take-off','Move-left', 'Move-right']
for i in range(0,7):
  os.chdir(f'/content/drive/MyDrive/Audio_controlled_drone/Dataset/{commandlst[i]}')
  files = os.listdir(os.getcwd())
  [os.replace(file, file.replace(" ", "_")) for file in files]

# %%
r = 0
os.chdir('/content/drive/MyDrive/Audio_controlled_drone/Dataset')
for i in list:
  k = 0
  for j in i:
    command = AudioSegment.from_ogg(commandlst[r] + '/' + j)
    command.export(f'wavdata/{names_list[r]}/{names_list[r]+str(k)}.wav', format= "wav")
    k=k+1
  r = r+1
